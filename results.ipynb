# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv('/home/rajesh/work/dairy_cps/noise.csv')

# %%
df
# Out:
#    Variable_Noised  Noise_Level  Detected_Cyber_Anomalies  \
# 0             Milk         0.01                         7
# 1             Milk         0.05                         5
# 2             Milk         0.10                         7
# 3             Milk         0.15                         7
# 4             Milk         0.20                         6
# 5               RT         0.01                         6
# 6               RT         0.05                         6
# 7               RT         0.10                         7
# 8               RT         0.15                         6
# 9               RT         0.20                         6
# 10           Water         0.01                         6
# 11           Water         0.05                         8
# 12           Water         0.10                         7
# 13           Water         0.15                         6
# 14           Water         0.20                         7
#
# ...
